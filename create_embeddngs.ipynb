# %%
import os
from tqdm import tqdm # Para barras de progresso

from typing import List, Optional, Union, Dict

from haystack import Document
from haystack import Pipeline

from haystack_integrations.document_stores.chroma import ChromaDocumentStore
from haystack_integrations.components.embedders.ollama import OllamaDocumentEmbedder
from haystack_integrations.components.embedders.ollama import OllamaTextEmbedder
from haystack_integrations.components.retrievers.chroma import ChromaQueryTextRetriever
from haystack_integrations.components.retrievers.chroma import ChromaEmbeddingRetriever

from haystack.components.preprocessors import DocumentCleaner, DocumentSplitter
from haystack.components.converters import PyPDFToDocument
from haystack.components.writers import DocumentWriter
from haystack.document_stores.types import DuplicatePolicy

from mysql.connector import connect
from mysql.connector.connection import MySQLConnection
from mysql.connector.cursor import MySQLCursor
from mysql.connector.cursor import MySQLCursorAbstract
from mysql.connector import Error
from mysql.connector.pooling import MySQLConnectionPool
from mysql.connector.abstracts import MySQLConnectionAbstract

from sklearn.preprocessing import MinMaxScaler

import math

MYSQL_HOST = os.getenv("MYSQL_HOST", "localhost")
MYSQL_PORT = int(os.getenv("MYSQL_PORT", 3306))
MYSQL_USER = os.getenv("MYSQL_USER", "root")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD", "root")
MYSQL_DB = os.getenv("MYSQL_DB", "jogos_tabuleiro")

# %%
# Test SQL Connection

def get_mysql_connection() -> MySQLConnectionPool | MySQLConnectionAbstract:
  print(f"Conectando ao MySQL: host={MYSQL_HOST}, port={MYSQL_PORT}, user={MYSQL_USER}, db={MYSQL_DB}")
  return connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    password=MYSQL_PASSWORD,
    database=MYSQL_DB,
    port=MYSQL_PORT
  )

mysql_conn: MySQLConnectionAbstract = get_mysql_connection()
# Out:
# Conectando ao MySQL: host=localhost, port=3306, user=root, db=jogos_tabuleiro

# %%
def calculate_popularity_score(
    qtd_favoritos: int,
    qtd_jogou: int,
    qtd_tem: int,
    qtd_quer: int,
    qtd_teve: int
) -> float:
    """
    Calcula um score de popularidade para um jogo usando escala logarítmica ponderada.

    A escala logarítmica é usada para normalizar os valores de entrada, que geralmente
    têm uma distribuição de cauda longa (poucos jogos muito populares, muitos com poucas interações).
    Isso evita que jogos com números massivos dominem desproporcionalmente o score.

    Args:
        qtd_favoritos: Quantidade de vezes que o jogo foi favoritado.
        qtd_jogou: Quantidade de jogadores que já jogaram.
        qtd_tem: Quantidade de jogadores que possuem o jogo.
        qtd_quer: Quantidade de jogadores que querem o jogo.
        qtd_teve: Quantidade de jogadores que já tiveram o jogo (pode ser um indicador neutro ou negativo).

    Returns:
        Um score de popularidade numérico.
    """
    # Garantir que todos os inputs sejam numéricos e não nulos, tratando None como 0.
    qtd_favoritos = qtd_favoritos or 0
    qtd_jogou = qtd_jogou or 0
    qtd_tem = qtd_tem or 0
    qtd_quer = qtd_quer or 0
    qtd_teve = qtd_teve or 0

    # Pesos definidos para cada métrica. A soma não precisa ser 1.
    # Favoritos e Jogou têm o maior peso, pois são indicadores fortes de engajamento.
    # Teve tem um peso negativo, pois pode indicar que os jogadores se desfizeram do jogo.
    weights = {
        "favoritos": 0.4,
        "jogou": 0.3,
        "tem": 0.15,
        "quer": 0.1,
        "teve": -0.05  # Peso negativo para a métrica "teve"
    }

    # Aplicar transformação logarítmica (log1p para lidar com valores 0)
    # log1p(x) é equivalente a log(1 + x)
    log_favoritos = math.log1p(qtd_favoritos)
    log_jogou = math.log1p(qtd_jogou)
    log_tem = math.log1p(qtd_tem)
    log_quer = math.log1p(qtd_quer)
    log_teve = math.log1p(qtd_teve)

    # Calcular o score ponderado final
    popularity_score = (
        (log_favoritos * weights["favoritos"]) +
        (log_jogou * weights["jogou"]) +
        (log_tem * weights["tem"]) +
        (log_quer * weights["quer"]) +
        (log_teve * weights["teve"])
    )
    
    # Garantir que o score não seja negativo (pode acontecer se 'qtd_teve' for muito alto)
    return max(0, popularity_score)

# %%
def get_mysql_connection() -> MySQLConnectionPool | MySQLConnectionAbstract:
  print(f"Conectando ao MySQL: host={MYSQL_HOST}, port={MYSQL_PORT}, user={MYSQL_USER}, db={MYSQL_DB}")
  return connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    password=MYSQL_PASSWORD,
    database=MYSQL_DB,
    port=MYSQL_PORT
  )

def fetch_boardgames_from_mysql(conn: MySQLConnectionAbstract) -> list[dict]:
  print("Buscando jogos do MySQL...")
  cursor: MySQLCursorAbstract = conn.cursor(dictionary=True)

  query: str = """
    SELECT
        jd.id, 
        jd.nm_jogo, 
        jd.idade_minima, 
        jd.qt_favorito, 
        jd.qt_jogadores_max,
        jd.qt_jogadores_min,
        jd.qt_jogou,
        jd.qt_quer,
        jd.qt_tem,
        jd.qt_teve,
        jd.thumb,
        jd.tp_jogo,
        jd.vl_tempo_jogo,
        GROUP_CONCAT(DISTINCT c.nm_categoria SEPARATOR ', ') as categorias,
        GROUP_CONCAT(DISTINCT t.nm_tema SEPARATOR ', ') as temas,
        GROUP_CONCAT(DISTINCT a.nm_profissional SEPARATOR ', ') as artistas,
        GROUP_CONCAT(DISTINCT m.nm_mecanica SEPARATOR ', ') as mecanicas
    FROM jogo_detalhado jd
    LEFT JOIN jogo_categoria jc ON jc.jogo_id = jd.id
    LEFT JOIN categoria c ON c.id = jc.categoria_id
    LEFT JOIN jogo_tema jt ON jt.jogo_id = jd.id
    LEFT JOIN tema t ON jt.tema_id = t.id
    LEFT JOIN jogo_artista ja ON ja.jogo_id = jd.id
    LEFT JOIN artista a ON a.id = ja.artista_id
    LEFT JOIN jogo_mecanica jm ON jm.jogo_id = jd.id
    LEFT JOIN mecanica m ON jm.mecanica_id = m.id
    WHERE jd.id IS NOT NULL AND jd.nm_jogo IS NOT NULL AND jd.nm_jogo != '' AND jd.tp_jogo = 'b'
    GROUP BY jd.id, jd.nm_jogo, jd.idade_minima, jd.qt_favorito, jd.qt_jogadores_max,
              jd.qt_jogadores_min, jd.qt_jogou, jd.qt_quer, jd.qt_tem, jd.qt_teve,
              jd.thumb, jd.tp_jogo, jd.vl_tempo_jogo
  """
  
  cursor.execute(query)
  results: List[RowType | Dict[str, RowItemType]] = cursor.fetchall()
  cursor.close()
  print(f"Total de {len(results)} jogos buscados do MySQL.")
  return results

mysql_conn: MySQLConnectionAbstract = get_mysql_connection()
boardgames: list[dict] = fetch_boardgames_from_mysql(mysql_conn)
mysql_conn.close()

print(f"Total de jogos encontrados: {len(boardgames)}")
print(f"Exemplo de jogo: {boardgames[0]}")
# Out:
# Conectando ao MySQL: host=localhost, port=3306, user=root, db=jogos_tabuleiro
# Buscando jogos do MySQL...
# Total de 1000 jogos buscados do MySQL.
# Total de jogos encontrados: 1000
# Exemplo de jogo: {'id': 1, 'nm_jogo': 'Old Dragon 2ª Edição: Livro I - Regras Básicas', 'idade_minima': 12, 'qt_favorito': 69, 'qt_jogadores_max': 10, 'qt_jogadores_min': 1, 'qt_jogou': 74, 'qt_quer': 57, 'qt_tem': 204, 'qt_teve': 1, 'thumb': 'https://storage.googleapis.com/ludopedia-capas/43761_t.jpg', 'tp_jogo': 'b', 'vl_tempo_jogo': 120, 'categorias': None, 'temas': 'Aventura, Fantasia, Literatura, Medieval', 'artistas': None, 'mecanicas': 'Narração de Histórias, Papel e Caneta, Rolagem de Dados, RPG'}

# %%
def prepare_haystack_documents(boardgames_data: list[dict]) -> list[Document]:
    """
    Prepara uma lista de Documentos Haystack a partir dos dados dos jogos de tabuleiro.
    Cada Documento contém informações relevantes sobre o jogo, como nome, tipo, idade mínima,
    número de jogadores, tempo de jogo, categorias, temas, mecânicas e artistas.
    
    Args:
        boardgames_data (list[dict]): Lista de dicionários contendo os dados dos jogos de tabuleiro.
    
    Returns:
        list[Document]: Lista de Documentos Haystack preparados.
    """
    
    print("Preparando Documentos Haystack...")
    haystack_docs: list[Document] = []

    for game in tqdm(boardgames_data, desc="Convertendo dados para Documentos"):
        content_parts: list[str] = [
            f"Nome do jogo: {game.get('nm_jogo', 'N/A')}.",
            f"Tipo: {game.get('tp_jogo', 'N/A')}.",
            f"Adequado para maiores de {game.get('idade_minima', 'N/A')} anos.",
            f"Pode ser jogado por {game.get('qt_jogadores_min', 'N/A')} a {game.get('qt_jogadores_max', 'N/A')} jogadores.",
            f"Tempo médio de jogo: {game.get('vl_tempo_jogo', 'N/A')} minutos.",
            f"Descrição: {game.get('descricao', 'N/A')}." if game.get('descricao') else "Descrição não disponível.",
            f"O jogo se baseia nas seguintes categorias: {game.get('categorias', 'N/A')}." if game.get('categorias') else "Categorias não disponíveis.",
            f"O jogo aborda os seguintes temas: {game.get('temas', 'N/A')}." if game.get('temas') else "Temas não disponíveis.",
            f"O jogo utiliza as seguintes mecânicas: {game.get('mecanicas', 'N/A')}." if game.get('mecanicas') else "Mecânicas não disponíveis.",
        ]
        
        if game.get('categorias'):
            content_parts.append(f"Categorias: {game['categorias']}.")
        if game.get('temas'):
            content_parts.append(f"Temas: {game['temas']}.")
        if game.get('mecanicas'):
            content_parts.append(f"Mecânicas: {game['mecanicas']}.")
        if game.get('artistas'):
            content_parts.append(f"Artistas: {game['artistas']}.")

        content: str = " ".join(content_parts)
        
        score: float = calculate_popularity_score(
            game.get('qt_favorito'),
            game.get('qt_jogou'),
            game.get('qt_tem'),
            game.get('qt_quer'),
            game.get('qt_teve')
        )

        meta: Dict[str, Optional[Union[str, int]]] = {
            "mysql_id": game.get('id'),
            "title": game.get('nm_jogo', 'N/A'), # 'title' é um campo comum para meta
            "min_age": game.get('idade_minima'),
            "max_players": game.get('qt_jogadores_max'),
            "min_players": game.get('qt_jogadores_min'),
            "play_time_minutes": game.get('vl_tempo_jogo'),
            "thumbnail": game.get('thumb'),
            "game_type": game.get('tp_jogo'),
            "categories_list": game.get('categorias', '').split(', ') if game.get('categorias') else [],
            "themes_list": game.get('temas', '').split(', ') if game.get('temas') else [],
            "mechanics_list": game.get('mecanicas', '').split(', ') if game.get('mecanicas') else [],
            "artists_list": game.get('artistas', '').split(', ') if game.get('artistas') else [],
            "favorite_count": game.get('qt_favorito'),
            "played_count": game.get('qt_jogou'),
            "want_count": game.get('qt_quer'),
            "have_count": game.get('qt_tem'),
            "had_count": game.get('qt_teve'),
            "popularity_score": score
        }
        
        # Remove chaves com valor None dos metadados para evitar problemas com alguns DocumentStores
        meta_cleaned: Dict[str, str | int] = {k: v for k, v in meta.items() if v is not None}

        haystack_docs.append(Document(content=content, meta=meta_cleaned))

    print(f"Total de {len(haystack_docs)} Documentos Haystack preparados.")
    if haystack_docs:
        print("\nAmostra do primeiro Documento Haystack:")
        print(f"Content: {haystack_docs[0].content[:500]}...")
        print(f"Meta: {haystack_docs[0].meta}")
    return haystack_docs

# %%
print("Inicializando o ChromaDocumentStore...")

document_store_for_raw_boardgames: ChromaDocumentStore = ChromaDocumentStore(persist_path="./test_databases/chroma_db_raw_boardgames", collection_name="raw_boardgames")

print(f"ChromaDocumentStore inicializado com persist_path: {document_store_for_raw_boardgames._persist_path} e collection_name: {document_store_for_raw_boardgames._collection_name}")

print(f"ChromaDocumentStore usando path: ./test_databases/chroma_db_raw_boardgames. Documentos existentes: {document_store_for_raw_boardgames.count_documents()}")
# Out:
# Inicializando o ChromaDocumentStore...
# ChromaDocumentStore inicializado com persist_path: ./test_databases/chroma_db_raw_boardgames e collection_name: raw_boardgames
# ChromaDocumentStore usando path: ./test_databases/chroma_db_raw_boardgames. Documentos existentes: 0

# %%
# Embedders
document_embedder: OllamaDocumentEmbedder = OllamaDocumentEmbedder(
  model="nomic-embed-text",
  url="http://localhost:11434",
  # Você pode adicionar outros parâmetros como timeout, etc.
      # generation_kwargs={"num_gpu": 1} # Exemplo se quiser especificar uso de GPU no Ollama
)

text_embedder: OllamaTextEmbedder = OllamaTextEmbedder(
  model="nomic-embed-text",
  url="http://localhost:11434",
  # Você pode adicionar outros parâmetros como timeout, etc.
      # generation_kwargs={"num_gpu": 1} # Exemplo se quiser especificar uso de GPU no Ollama
)

# %%
# Retrievers
query_text_retriever: ChromaQueryTextRetriever = ChromaQueryTextRetriever(
    document_store=document_store_for_raw_boardgames,
)

embedding_retriever: ChromaEmbeddingRetriever = ChromaEmbeddingRetriever(
    document_store=document_store_for_raw_boardgames,
)

# %%
connection_mysql: MySQLConnectionAbstract = get_mysql_connection()
raw_boardgames: list[dict] = fetch_boardgames_from_mysql(connection_mysql)
haystack_docs: list[Document] = prepare_haystack_documents(raw_boardgames)

print(f"Total de Documentos a serem escritos no ChromaDocumentStore: {len(haystack_docs)}")
# Out:
# Conectando ao MySQL: host=localhost, port=3306, user=root, db=jogos_tabuleiro
# Buscando jogos do MySQL...
# Total de 1000 jogos buscados do MySQL.
# Preparando Documentos Haystack...
# Convertendo dados para Documentos: 100%|██████████| 1000/1000 [00:00<00:00, 38658.60it/s]
# Total de 1000 Documentos Haystack preparados.
#
# Amostra do primeiro Documento Haystack:
# Content: Nome do jogo: Old Dragon 2ª Edição: Livro I - Regras Básicas. Tipo: b. Adequado para maiores de 12 anos. Pode ser jogado por 1 a 10 jogadores. Tempo médio de jogo: 120 minutos. Descrição não disponível. Categorias não disponíveis. O jogo aborda os seguintes temas: Aventura, Fantasia, Literatura, Medieval. O jogo utiliza as seguintes mecânicas: Narração de Histórias, Papel e Caneta, Rolagem de Dados, RPG. Temas: Aventura, Fantasia, Literatura, Medieval. Mecânicas: Narração de Histórias, Papel e C...
# Meta: {'mysql_id': 1, 'title': 'Old Dragon 2ª Edição: Livro I - Regras Básicas', 'min_age': 12, 'max_players': 10, 'min_players': 1, 'play_time_minutes': 120, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/43761_t.jpg', 'game_type': 'b', 'categories_list': [], 'themes_list': ['Aventura', 'Fantasia', 'Literatura', 'Medieval'], 'mechanics_list': ['Narração de Histórias', 'Papel e Caneta', 'Rolagem de Dados', 'RPG'], 'artists_list': [], 'favorite_count': 69, 'played_count': 74, 'want_count': 57, 'have_count': 204, 'had_count': 1, 'popularity_score': 4.164482969778043}
# Total de Documentos a serem escritos no ChromaDocumentStore: 1000

# %%
try:
  connection_mysql: MySQLConnectionAbstract = get_mysql_connection()
  raw_boardgames: list[dict] = fetch_boardgames_from_mysql(connection_mysql)
  haystack_docs: list[Document] = prepare_haystack_documents(raw_boardgames)
finally:
  if connection_mysql and connection_mysql.is_connected():
    connection_mysql.close()
    print("Conexão MySQL fechada.")
  
if not haystack_docs:
    print("Nenhum documento Haystack foi preparado. Encerrando o script.")
else:
  print("Inicializando componentes Haystack para indexação...")
  
  print(f"DocumentEmbedder inicializado com modelo: {document_embedder.model} e URL: {document_embedder.url}")
  document_embedder.run(haystack_docs)
  print("Documentos preparados para indexação.")
  
  # Opcional: Limpeza e Divisão de Documentos
  # cleaner = DocumentCleaner() # Remove cabeçalhos/rodapés, linhas em branco etc. (pode não ser necessário)
  # splitter = DocumentSplitter(split_by="word", split_length=200, split_overlap=20) # Divide documentos longos

  writer: DocumentWriter = DocumentWriter(
    document_store=document_store_for_raw_boardgames,
    policy=DuplicatePolicy.OVERWRITE,
  )
  
  # Pipeline de indexação
  indexing_pipeline: Pipeline = Pipeline()
  # Adicione cleaner e splitter se decidir usá-los:
  # indexing_pipeline.add_component("cleaner", cleaner)
  # indexing_pipeline.add_component("splitter", splitter)
  indexing_pipeline.add_component("embedder", document_embedder)
  indexing_pipeline.add_component("writer", writer)
  
  indexing_pipeline.connect("embedder.documents", "writer.documents")
  
  print("Executando pipeline de indexação...")
  
  batch_size: int = 256
  
  print(f"Processando {len(haystack_docs)} documentos em lotes de {batch_size}...")
  for i in tqdm(range(0, len(haystack_docs), batch_size), desc="Indexando documentos"):
    batch_docs: List[Document] = haystack_docs[i:i + batch_size]
    indexing_pipeline.run({
      "embedder": {"documents": batch_docs},
    })
    print(f"Processando lote {i // batch_size + 1} de {len(haystack_docs) // batch_size + 1}...") 
    print(f"Lote {i // batch_size + 1} processado. Total de documentos indexados: {document_store_for_raw_boardgames.count_documents()}")
  print("Pipeline de indexação concluída.")
  print(f"Total de documentos no ChromaDB ({document_store_for_raw_boardgames._collection_name}): {document_store_for_raw_boardgames.count_documents()}")
# Out:
# Conectando ao MySQL: host=localhost, port=3306, user=root, db=jogos_tabuleiro
# Buscando jogos do MySQL...
# Total de 1000 jogos buscados do MySQL.
# Preparando Documentos Haystack...
# Convertendo dados para Documentos: 100%|██████████| 1000/1000 [00:00<00:00, 24942.64it/s]
# Total de 1000 Documentos Haystack preparados.
#
# Amostra do primeiro Documento Haystack:
# Content: Nome do jogo: Old Dragon 2ª Edição: Livro I - Regras Básicas. Tipo: b. Adequado para maiores de 12 anos. Pode ser jogado por 1 a 10 jogadores. Tempo médio de jogo: 120 minutos. Descrição não disponível. Categorias não disponíveis. O jogo aborda os seguintes temas: Aventura, Fantasia, Literatura, Medieval. O jogo utiliza as seguintes mecânicas: Narração de Histórias, Papel e Caneta, Rolagem de Dados, RPG. Temas: Aventura, Fantasia, Literatura, Medieval. Mecânicas: Narração de Histórias, Papel e C...
# Meta: {'mysql_id': 1, 'title': 'Old Dragon 2ª Edição: Livro I - Regras Básicas', 'min_age': 12, 'max_players': 10, 'min_players': 1, 'play_time_minutes': 120, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/43761_t.jpg', 'game_type': 'b', 'categories_list': [], 'themes_list': ['Aventura', 'Fantasia', 'Literatura', 'Medieval'], 'mechanics_list': ['Narração de Histórias', 'Papel e Caneta', 'Rolagem de Dados', 'RPG'], 'artists_list': [], 'favorite_count': 69, 'played_count': 74, 'want_count': 57, 'have_count': 204, 'had_count': 1, 'popularity_score': 4.164482969778043}
# Conexão MySQL fechada.
# Inicializando componentes Haystack para indexação...
# DocumentEmbedder inicializado com modelo: nomic-embed-text e URL: http://localhost:11434
# Calculating embeddings: 100%|██████████| 32/32 [09:09<00:00, 17.16s/it]
# Documentos preparados para indexação.
# Executando pipeline de indexação...
# Processando 1000 documentos em lotes de 256...
# Calculating embeddings: 100%|██████████| 8/8 [02:34<00:00, 19.33s/it]
# Document a985004ef08208e7039f7b4f4dd4aa66339e12fb99d8413417074065b196b6d0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a1696e9dadff5b3405ca2ab23eceb32f6404e6e0e5f4fe05c5aabcf953a56afc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bbb78f1e404935668f42d0dd203bf07ec5ef84f3530ddf73db3f245ebee52191 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b0c2603f0d706fb9d3d07a8a17533cdb9cb7de85dff64db0760de046cca138b1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 63061dbc1c3caa5ab02ffcd5ae04a6ca2e521dc4dd0fe3ed1c3fdaa7931900b6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9636f59462ba05770518974b6deeec2e3d08a9eb17169ec012949fe5a5f0f0dd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 55ff75cda8b335d3dee812f1c3d6e19b93496d1fd7886157cfcafdc3ff55ecd7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e3b8a9a94ebf00d1603f5134903a6c5820d180b9116c098416006fd0de6db241 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 52ca444a66cc736e512abf3177c3669b7fad0c0216ffaa2395a920da0c21f3df contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b0efb30348052e1ccf274174651e07f48efcbdd55ede27248a64ad8762d08254 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 139055a20ef638b1e077bfc762e6d7047a2b3ee7ef14f5c3cd3d4e2d8f2c39f6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8d8316fbce7e16d3cbe95a3391899f1aeb26b5bccd281a4be9640d60d32c660d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8430f4672a7a4a2815da847a4cbd7022351bcac14770491098495a67d1597dc7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cc318a5ceceeea8844ddd0aeb84ea9f7e9ee790c5de18772e3c5529f18e2f6aa contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 03ca119187b98469eff0f45412798fc71d1654180e5ccfdc6b7da24e5f0d8441 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document be23dc4aa55afdf546db390da3532ace6c5dd718785246314bb927a0dd3e1c26 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 25551cd09680a577fda5a7d8abda581ccf2863534c0a79ea51886a38ac680c25 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9b0d10268cffb3e0ac4c8d1cab02f4982a648556ee18d717532e2e12698a0d03 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e993b0ff4c291127214ce9e325ebb81b443a4e2030d25f8042ecdb4ffdee14be contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document fe7f13ee969c799c54c177fbcadef7b0b62663b3d0e34124adef614e846a4bdc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3483e1d61e03a167ed44794df64990dbf703fa2a6d540c701d274492d7a753de contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2a80869bde4189156109f6ade6c26705407e9bfb2033b86b7ecc8a4676429e69 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a800d0442c66a61224f3a42f728819b59f1e357fe3aceda1c154bf4992e28b88 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 058710eba9ecc8357703fb849fbccfd142a67df95fffd9c52679123f9dea5fd5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 566e0abe089ab20fa3fc7601eba91c4ec3af863f44f32bf09964d05d58307b73 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e9f60b3e28bdc45a218632374099c94f8db625f354d08fad8abf607517941e27 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cfd8a1e0cfcfd4add9b38947d1b403090a4c3842e45a30d30e29a6b2364bf236 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 36bc7112dbaa024926156869e821ce50c1b1c132fb4be4e16299f7b2124c8eb0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e2ce89c4bf8a096e088d6f7b0890fa08e0886729c7808462f8e7ff40a6e2f744 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3975e716aec75015bea0f05e44a4f08c536259a398c188e94c301f313d103aa5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f4635bacebca2f9e825ec65c1796d266e5b96e02e639e38752885e1e6c41466e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 10d8ff4163385dcfec92a93ebdf04d0b0a5798a0a5bc356190919a2e0dc7b22b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e2896e2e50f7d6f0c7810db70033e933bd05cf85926776d4d3b4ebc52230ce78 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9af145f405c45b453673950870f17ce9d8c46ce26d0e513c68c8a2737fc7aa2c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6de7714f30d803f38c5468d99e6f2a1cbf6540cbec8c9a3bbb6be74e99a4de20 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 03fe1bc8129b58161405c8da11f21330d2540a1843d5ea5a7e39299878b1571a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1e4211e5d071ba88ef946485aa3d260a4d5c483a55a5255bf1dc26b396b2a8cc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e1822123a7d2b4aa521dd0f555f1d88134df42dc55a9bc7a39d108568388611c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 16c63c08b822f27153758985dee4b914747543dce8463b72f6a7a4250fe3639a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a2ad53ada1fec9b329118efaab2111b7c9c774099eb161027bffb10d460c1f40 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a935a5897d6fbc58d381e154c184143203f20cd15c19cc9abf2ddafacc0c177c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ce4c5d8c81d09a6bb26ce300de4a19cc298dd68067a69dd0443471188488ccbf contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9e2bdd05f8764d84c877470175e506fdd9e1f90117e006f7dfb73c1049521af1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4a31f305085cccf873d1e17293f1d8b887805d34b29538941f190346f2434728 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7bb91b34223461601f6bf90cfe25dbef8ab0963bc20acaf19121d07f46b41ce0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4a3658ebc515bc0d1d7dc3f2d1dc21af8fc88e936676cc11712c9b763b71fbf6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9f7d79821dbd363fd7b334a2867edcb548e10d51b9363840e22866624f459c58 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ad60cf8d1261015ba4bb0deaee94c3ab28a4cdbbc26d2be0668b3024e94e601a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 187a263b24ab9786bdc9586202619d9d0c927c5e0368b4cdcaa74ce7cc496a60 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 97bce5b1a639d83767e008fe681f7468daaf4b9de8d945f67211b6e1dafda8cc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c45523aef48dbea54330cc5d2d6de5b8ee52476db03e83e472b281fc06b173be contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 531f82bc78d360bbe0805ea6b7d0cd604682ca33f9168bd70428aebf73437cde contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 079ee262ed6e35e94250b44e8fc0e2dd48bb8f1b42fce59fa60b654285e8cb67 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 818da4cfc46a84d58f37900d603e1e78faf27ad84a196a5932a8c721fa2a002f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 455e316180494887837876c4be7bc186e50c4d10ee73843d1e1aec7002c64d98 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1cbb9ec60cb6510f1e7c1f40a93c079468aad89083254cd05a3ed21458a8bdc6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d4421dad67acc5bc9a503581dd2ab3403a1e68c56cad302b67308db027530b53 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 129dcb3fc21c1a87036ae79719e04b3b5399f593db6e1bdb5a53657159cdd54e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c592f0dee683ee033eb897b3b65acd59167ad3216093d7c2993e5f9c1f02946f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 40c581e6d20247e38b8ba911f42af7168204d30d49f8a015d6002c0be6ac6342 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8d765d8247c01ae54b4c231d36f8605685555a7fed3a1dc5bf2eb64bfdcc8bac contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 02b462426aed39bb6d8aa6f110c9e4520c2ed1112fc7eac175af25d7e69a2053 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b0cc0c9fba433e6c3f407a59f3b157ccd66b7bb8bd5e8f36a617370b275dcd2a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8ee3f93261a09a0f3f701ce06f45b9e2cc68ef18d1ca26e3fe0c5574b13d48e3 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7864113bd36a875cb18ec0b1313886f289e213f71e9b85cdd6f0cc9cb2a04f4b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5b7c6967abb4d579f4a24af1a4bc9d6ac88d4e4e4b75cc37194277ae50d679a1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7be261b9e39c98fe2bffbafbfb6d4601da58c5e04312fdd6fcc4d69c77ec3e7a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8a58f91f6ed7fe9b8ce52fa85383cd6fd17fbbdd23f7667d76d369136ca15e8b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 642f242f1030b6039fdd7744552d589c96dbd68fa35783daf0bdaf0a1b88f062 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1833172e983dfcabbee9a13373bd67bad55f5c6130cfd3468ebe738bc1f8a930 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8a35ca4c250e47754fef34378679ded7c8e9f6c436dd3aa00ed5a5505a87cce8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bf312f4dd8cae73dfe24627c867db410b847061f60cb59fcfbdeff4ee84e6b8d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 33b2030952d11f5e6631659ca665ba431ce8f479f5da61487e04e693f7f60301 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3b432a6df88073d76dcc4a03ed5959b70c31ccaa6da0f2f8d942e6dd69a8806f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ff82c90cfeb1aeb5e9629a3bb69e99196bafdd8b237d8b7d4606ed14badfbf3c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7b1af723a8002ca703bc38bd311d1d023a9222eaa99de09d87c051e9c84673ea contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1302d7495df3107be8cda3fe0c17252e4dde32eac1d8787d3f5761764400c6b9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 692bb4b3c19d1cb05eb9be8f18296c15047479f83edf375d0e3fe86d4b3ab72c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 33c9fe00fae2f95b4e1b8df5d92e67fabd420c7622ac2406ce854e2568ce4b16 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7b4ed50d81da5b3e3f2199b8ab371464dd36aa386974b948676f95a791b0cb2d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0270091c7320ab7b78e311fe4bee0eea34c5d212072a3a0450b8a2182b5367f2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b3f1e12c6b3cb5ff80d6da29e2cafb58c856eccc1c4253dcfe91dcb96e5ebc35 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 077ab6add60b4e52e2b9f1c93f1194336d541d1121ef001d17957c555d1d8037 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c355ead7cd0d2f3a3414b123d98359c15602fa42cd8507040222a0eab0ec5425 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document eec477fa52d5c1d103eea9035e798f1535ead6769a4cf18041f5ea735568d103 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2a0525035f7bcd34bbf642ac4d1811b528c642057969c29a53211c97330897e8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4a97cc6f8f6a6115eda03d6d9c342d39e8ab93d49cd0acab7b48793138bd3481 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 740584c9bd523438a33fabdf8d56fbec12497338c00676399c8239b6e7fc7f6b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ef239d72ecfb99fbbe6a34d7810fb8eaff1b38286828ed48b526ff538106dd4c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d07a06a14e2311ef0c2876a4802fa8601efe89e1448a167053eb6865c57f730e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 85d12e50df497bd40d3e7350b453ac5e86736dee52667f28e7a276c0315d1bfa contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 69014385e1869831a188e0fca7d5fca3c92a08d9efbbb80d0fb1761cd62b101b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d9ed226b56f640293083602d8e772ff93a923fc0b4f80b881bd0ba5ecd44aedd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e19110e39504aecd8ddf06ed66b6e72229d8ea3612ac7a1b583614afe7f10368 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b3ab5983fd5da5df226ad2b5d7172dc35bdcff4c52eece039ae5e78aa004edc6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a494ddf958d0ade4389acfe1dcf1e008ac936baaba326821d0d2f122a3417f6e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 111c3c7ab68130846eae1f8350c25dc053f0497a6b83b6330a04826bf4cfff11 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4368f6a3146aa88007e814ab60d7328f0a46c17226b835c9726f182f2ec04b39 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f68d8524929c0f373eb2e281049c6b396bb8a9015da57f6aa715be61d2177dbf contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 46fb6f1ed1523f69a20869230ab61c9f345ba3b370f0f7ebeb8d66936875a686 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e24b2ba4955e4601792ae0848dddf4501ba6968d0911e250d28594a3d8983e13 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 451fc7fb3bd8c5a49baf1c3ce9d40fae91b0c8025af9ffb8eb5d23b69e005afc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ceaa27eda86637f97c9a5fb10a078c2f2663ca3d7c188121ae0ffa1083653afb contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5370fef1cec52f79b1feae605a3df5bb642eca9c6eee634523272fddbcfea130 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b3751f06b9564fd4a8739b1f56d3b575cf55420d1dc01c6471413be1921fd455 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document dc03f3fe45327dcd1a3e9d98a73902815e6b57aa20e0d62bc1e39b0e32ada3ba contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6eb177b5f0b56a5e70bf8e3f688ab90dd45c92a7764ae26271ae34ceba6bd356 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 059117fc6e764dd1fb3ea32d823ebf7a9aace99faecd5480a27969a36edfb25c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b648c04a7d6031c9f06671890c0162466f2c7120d4c761af13da5e2206ed2380 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 00b14c3e380efd1d82856bfbf86e2f612852dc03a9e9875f062d0b4cc5a0fa2f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1ff5331e042bc6d7d7b2c8aa6286ffbec1a5599b2cf1d0485ed4c41cb6ef8b05 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1b6621e6254221e1e4c9774cd6d470a721ab091fee0b540e669f7931ea76422a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d5f4b000456255de6edda7c15882184990f7bc4a691085534d8e76990839750d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 79be71dc3240e09868a6352548c7775f4886e1cfbbf155d0c1f691d65c651cd8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f0d04cb5074885d019de6e0bac2d0a6b98b0fe0b9507c9654981d79da205da8d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ea41a72014513e174842db31f784106e07bcfcaef7ece2861b03c56e045ccd23 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f68ea345850802d92fee7ef826fba00f532edda2669e38620c7992f09c16bf42 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cf965334a0d35bafa6e8be9edd0281fa2487448f1279fdc8bc6584873a4dade0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 087ac92d8493ddfaf0cc9ddcc68ae40cba0f938a8a5cda908ae8257ad9bba1bc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8308cf64f88089630cce5e5db2e40be3de41470cc7850d4d0037724a5e1524b9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4a22619731b9cafc9abb0854784035fad0386373514e434af8714ba327241f80 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document fd03f311fa2f7deb9efd05360291a63409390cc421a5f9345d5e40d150ea0c66 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 47f60c2101ea7df2f3619429603ca8b3132032b2e876fb072a4a492586a24f0c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 454b66ef725010b48381521a72786e88fb305ad1bf8f1bb4ae0331c81372ef84 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f761f5c04da8c668b84bbbaae57e765dea72bdf52793be08ea54b68f22416258 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e9d16a1bc4b3dd5ee0c5b99b109cd7ea0b67063b45558b37b0f9084791a0dac3 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9a41e2825a58fe4284d245e9af2edae77356ed1d662bcdd3bbbe31855a00a709 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1432e0d957f599f5f6c5c79c1f95037521cf54f8825da429cdc29320a8345d44 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 41d57dad6d01d11ad914953e44cea5b4a43fbd521d76e99a1022925a821dcbc0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4debdbba7c282fb4542c55ea283ce13a2fc2ecdaf4f95147c95d841141b31ca7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 673bb53a8ae367ff290b9699a8664a8b7e670e2dd2354bc4f5226bffed8b0f92 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 639ea7ed931783869c191581a18ba8eb5310f73fe151b2fe9724dd7270943491 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bc140d4087318da2bdc14bf7e414377a1be79c1291ef17bc63722d477e5e5473 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cb19497037b6b514e7667c283f7282bcc1cb484b6cf75d828edd9123dceaa23d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9a489b4761d9ad73c5529e4e8d4228104a34634d34b437661bba638094055529 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9adb48754c90641bbfd8729ce1fffe735f551ed2b92b75823cfd718ecb46a7c7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 212ef56a691bb407386537d2dc99bf50ef7d6eb6f65120035426b4c41e157492 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c44615a3ffab3d2957a5b5375836a3ce5e07ff7f4e243e6caabf2da2f8a656db contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c807e1b68eea4c9d79ceb7a15c680163034180231b0eee43ace56d58e60dc2f4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0fc2d4a90a61cf94ed9149edc2c1476ed93932e246541f1285629d8e02302094 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6506b74e0189918fa7e477e32d0536f85310d51a2f9779ee187f927c8d42aacb contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0d9049c47086a467e1cca148c7c95d0d3e4bec5c2dd2ef749d3bb744f9b06b85 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1c8dc193ad0977c058068b5c138de68779315bfff9b1b2fbdf3bf85e4ccf5dcc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 82d3af31a1c8f762d65c242535bb960732e732eb8634636a7c2831df40fa1278 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7384595c3c83effe68c4d45241c780426148050167a95e73c32499b544ef6a99 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 55f84d72df2800c50465c9c55dcf4d63215699d6ddfe03700af2b10c7538c5c7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7d431f895c4400b748e6c5aefd38622297d1e8d2607b499e421688ac24655594 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7bf200a5b2143a2fcf034fa7082d8a159ec3005ca8fc65ab76701d7661454707 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 975bd568bb75a44a8577dca410b15821c3adb3f6be80141f147bf1b6b9e9e00f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bf6c26f647aa578fbf34883f32abbb5cbaef7b85623e55733bd40e4a8575a8eb contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e76342e9de084713fe1f31fa5e8b502d214b3bdb3e869ee89ef64eef875b11d5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document afdd5e32dcbc78d21667601b4c4926738c0a85765718b2e6fdbc77f0aa0b9bb6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 34ec9a0f1ced56c2bb2d6f663d9c9cc21e4ff3ac33840a7134eb63b16da472f9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 471d0882e249e8261cd8ee912a1ca2331e67f583f873e9b8e9f34f9e9a041193 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 404bf730497789201afad7bc90c0826c7f1b3157143d8dd03f9d1cf24335f94a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 789e8caa3a5dbc58c3db215184a792de7bebe3687ff217ac30b11390bd54dca2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document afac5d4fc3186911578f5886860d939ca08f39774ffbb90d95e1fc36fea209fe contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 12b8550851c7202d2ef8c3d33d152947032e0395682ba7c9d82cf6182e4c237f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cd6e62203db6c55b735ac1edef97f4d7aaf1820274a6303f9e97c2a728141e2b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document dc45e4cfd2aa2c4e41272c7b6c956a2aa73ad9e074e51cfa26bd8bd00139ef48 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 31fbfe64ca817c24ffa0403bb248d903b13db1841e8764668080f03ce443530c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 15610f1eb97cc7af0fe408894becad75d647fb1d74ecad54dd024535f286bc67 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7a6676bad6317211248fec039c0f3f6d9539b915ac7046f05e0d4c7baf632d2d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 260a2053a1553f066a32b8d7debc78c9393f204b9129833e2b474040720b0b2d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 24c3024934537700505cfdb1f87fd8b4d449132d6d7ae289761ffe58f1a1c60b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3a71557fcae381191c526e509c7e231ed2cf2fd24339db509e274eebfae2e04c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document dea97a0ecdb314841a941a612b9d183b3a0d9fabc69c8d3b808725a7ada31efc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8f09015c93ee5280fe04ede7b9b9d337cb7997bab06929ba939477e434ea2402 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a29fe1fce1feeb0d3a4a29ef64d9e0261cfd1c2a3a50ee95ab0549596b48ff14 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2c27d7d88e59de1d04b82d5a4a996e99a011f2019d3ac033a2235930647738f4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0826c14b77d03b209acae2c1eaa03f2bc8a7d4256663c5cdaa4c666aa8bf9f6c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e22886636d71a226b45f8387bccf4458a58697a1e2f40fcf872a76c915071df9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# ...
# Document 3e364992ea22173b7bc444b6eacc7a1627b3e179aca27804fff62dcc07cf4052 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f736099726ec6e55ce970203b328fd2cdf4af080bee35804271f173779929e29 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3912e9418947522ec00dbcd52a1b8702e25934c07e4fd2c38544f8b67292a20a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f799f164f1c8b945083ca8e15f50be1fcb5f86a627e352e8dbb9f6420ede2b38 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0fcd79b4be3313625aec0b2c3b3fe11a730268e176d1dd3c15709245b4624f20 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9daa897296dd567510512bfd9f8a590e0326b8cedf57458ca3c3da7ed502c519 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6e987e28ddd41a941687e508f3a72f506387ae402806eb65d53e4213b63aa530 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 810222fab79fb06338491499190fd8de4a14c21e08f3437b1ae96831b439ad46 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document abb40aa96fd12768c41b0641cd07e294ab73f727240d440659d66c86e6bfc625 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4e7efab24ad8df63be71775be53fdac2d111c8ee54fd618fb245e3332a36fbfb contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 32df6342d8151090ed55fa7342ead3392138ba61f09a1255987c4b596d620aa3 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ddc1842bafb3110c8fb146f7fd4fabb7060f21fcb5396836319075f5a055083b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7d1e70eaa1b6c12676bcb1d18502bddb7dce0d5d0501d2dfa07192b3c029a024 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 869a9d4b5cea6f49b69637004a794d71286938081a52795d11a49b6a8094836d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d1e09e64a2cedb883a280e50b5358568c99c47e293c65589448203c13ce79ac7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9ec2cc47a639697891c51500013b875d29260f22163626e92024f35dd5c3e5fb contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6753f6739b1e6923e35bd284408e5ca417db914f30a7fd6bf38a154ab65c19b2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e64660d9dd2528bd25b37095f577191c50808499e2492d74df4675f61cc15cf6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 85f0e1217882aa715048a36ff3efd7a46198c0a2e5c65c7a5dca5b5ebff6f9e6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5d5a327dda49126d0aa392fd68784bef6c4cb5914faf6987da4de123af3d7bc1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5db96eb29fcfc1080208cfc57df76df1fd9c53bad56faeab1500bcaf1153e61b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 75981607ac9a1fae6b0c2a39fada0baaf8350d15fde5a2fe6d4968c40c01e65a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d39e067d15b13f9841ff8e21d85333aaafec10f71556227e29b7591452a7df1a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9ab97e762998ca1890c33d077c27858dcb0f3940c2886acb357f352691d36283 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 06206b52cc89436150380ba30f6b1570aa15ba67abd321524aedefe0f0026905 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3990dce9279eb0ce9c7cabb1d6339e7afc92e836a863cb683685fb623ca7adee contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 489fb716ecc4730ecaafca05216445faa29d1b818f48c1739fc9ddacb8142ec5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b4469364863e0ad9580ba7d149ee328a19426b691d5e59ad7c71022b0a124ead contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e346d078b1b5b3324e47fdf3ea11f398f41bad47444a2f16583e8fed10a08d5e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 62bd58f2a5d52802ba531046ebe023df8fe5222ce21683ab419c32047db52503 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7af59e970b9a709d5798304f20d476e70f32a5eabddd51891de3ac30cbd30417 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6b8b141fdbeff877b8da7d648adc29dfcefabb31f812a28781f623bb2a351a6a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4060635d38492adfae59c799e1aa439af5e52d849d7bbab3a3c233c61ce04da1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4bf184d78f2810821a14288e38fd24aa70f0c232ef2495649dea673007f4168c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4ddaf17d5f6b4e62630be1df7a6a5d15218d5dd42724359cea307dd9241d65a9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 868c160a12f5e07824b72439a82d1e61048645a3fbfbf34f605ad253be670de7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1945cf54ad481c08cc1db04643e59f55531b8eced92319aa0f158026ea5b7025 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 684e2edabcfca24eae218eb7dc8196b0cd476dab5d72f29f21b8dc4a75997940 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d9c834eeaea6cdd4851bbf3357a7f82962b4f7b81821b683cba614cd92ba664f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1e9234ff9cc52019dd377db2ce9a22fed44745d40421229dd3eecc2fb72ea7d7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2c2657fadc41736ce213a7d206c2553498248011c96db7ba1892de9cdb77da4f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 12a9ebef51aee69598c7f55fb10206a8676baf7556eb58248b42e56de07442af contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 16b82fa8833136d49d81bbf38792ef1ec592a5ce895231da957639336771849a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 00a07f2fc856f501671a77b5566e332768af1037a43b3745dfd6b65e0eb9dbf7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 41c694005dd9c2d58b69ec851c0705b727b1b17539aef404966df86828db0cbd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 13a45e48d2a8dc368e8a02a503f9495b89bfacb587ff2addd0fb51e6f9854875 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cdbd08bdd63529699d9150bf188950fc026217656c976b7b7e95c4c693e901ca contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3ca4581784e760af493e72702a9b9665ab39f61fbf7d443289b55b871f1a80d9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c33cd03948d42f8ff21a4546a9fb4680c86d19f2d41de1e0fcee845f55dbaf06 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f94e243e004a677d4c7f3bbe6f600e1ad1b2a02ae77fe9e502e19a7f4cd4f510 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9f44b8861e673f0e9c4caf1f2347c07234c27d5c3a6dfa8f87e2632ac869bf49 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b2466f52399e44ae32bca9c09ca2405fb9dea263c8ca7f0e14d412a4d66620dd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b2f57a270ff4a62d0a0b4230a2934422070d9c2bd4914f767435f54b6e4d53dd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c3c7be10fa68d8c5ca172357802503675e3f60a64c37cf9e3329ad901e500f1a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2a5754c18c0c9ee4c5ef206c10193bd7480fd4e360e1a5c842f9096080580d9e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4ec6dd84e4aae7a44f76b7c049968644914d6ef2c685c2d9db0d4d5b90281cdd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1f32e5a6d4494839b6cfb73e93651b622a96bede78f10cbd7089c61fabbe4568 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a90101d7cbdee8133579e545623ac4b32d90d49f59563e2599162e7da8a2a963 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 88db9f3e3583e099de46f32b8e18d1f0ad98571a6a7f8053c23c6759839b98ae contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Indexando documentos: 100%|██████████| 4/4 [09:46<00:00, 146.54s/it]
# Processando lote 4 de 4...
# Lote 4 processado. Total de documentos indexados: 1000
# Pipeline de indexação concluída.
# Total de documentos no ChromaDB (raw_boardgames): 1000

# %%
print(f"ChromaDocumentStore para teste de query inicializado com persist_path: {document_store_for_raw_boardgames._persist_path} e collection_name: {document_store_for_raw_boardgames._collection_name}")

query_text_retriever: ChromaQueryTextRetriever = ChromaQueryTextRetriever(
    document_store=document_store_for_raw_boardgames,
)

print("\nTestando Opção 2: OllamaTextEmbedder + ChromaEmbeddingRetriever")
text_embedder = OllamaTextEmbedder(
    model="nomic-embed-text", 
    url="http://localhost:11434"
)

embedding_retriever = ChromaEmbeddingRetriever(document_store=document_store_for_raw_boardgames)

querying_pipeline_option2: Pipeline = Pipeline()
querying_pipeline_option2.add_component("text_embedder", text_embedder)
querying_pipeline_option2.add_component("embedding_retriever", embedding_retriever)
querying_pipeline_option2.connect("text_embedder.embedding", "embedding_retriever.query_embedding")

results_option2 = querying_pipeline_option2.run({
    "text_embedder": {"text": "jogo de estratégia para dois jogadores com tema medieval"},
    "embedding_retriever": {"top_k": 3}
})

if results_option2["embedding_retriever"]["documents"]:
    print("Resultados da Opção 2:")
    for doc in results_option2["embedding_retriever"]["documents"]:
        print(f"  Title: {doc.meta.get('title', 'N/A')}, Score: {doc.score:.4f}")
        print(f"  Content snippet: {doc.content[:200]}...")
        print(f"  Meta: {doc.meta}")
        print("\n")
else:
    print("Nenhum resultado encontrado pela Opção 2.")
# Out:
# ChromaDocumentStore para teste de query inicializado com persist_path: ./test_databases/chroma_db_raw_boardgames e collection_name: raw_boardgames
#
# Testando Opção 2: OllamaTextEmbedder + ChromaEmbeddingRetriever
# Resultados da Opção 2:
#   Title: Torres, Score: 398.6153
#   Content snippet: Nome do jogo: Torres. Tipo: b. Adequado para maiores de 12 anos. Pode ser jogado por 2 a 4 jogadores. Tempo médio de jogo: 60 minutos. Descrição não disponível. O jogo se baseia nas seguintes categori...
#   Meta: {'favorite_count': 24, 'had_count': 121, 'play_time_minutes': 60, 'popularity_score': 4.370976742970466, 'played_count': 514, 'game_type': 'b', 'max_players': 4, 'want_count': 331, 'title': 'Torres', 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/939_t.jpg', 'min_age': 12, 'mysql_id': 854, 'have_count': 329, 'min_players': 2}
#
#
#   Title: Xadrez, Score: 398.7942
#   Content snippet: Nome do jogo: Xadrez. Tipo: b. Adequado para maiores de 6 anos. Pode ser jogado por 2 a 2 jogadores. Tempo médio de jogo: 60 minutos. Descrição não disponível. O jogo se baseia nas seguintes categoria...
#   Meta: {'favorite_count': 243, 'want_count': 57, 'play_time_minutes': 60, 'max_players': 2, 'game_type': 'b', 'had_count': 271, 'popularity_score': 5.811693311988799, 'mysql_id': 253, 'title': 'Xadrez', 'min_players': 2, 'min_age': 6, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/755_t.jpg', 'played_count': 2417, 'have_count': 2133}
#
#
#   Title: The Castles of Burgundy – Edição Especial, Score: 398.9562
#   Content snippet: Nome do jogo: The Castles of Burgundy – Edição Especial. Tipo: b. Adequado para maiores de 12 anos. Pode ser jogado por 1 a 4 jogadores. Tempo médio de jogo: 120 minutos. Descrição não disponível. O j...
#   Meta: {'have_count': 392, 'game_type': 'b', 'title': 'The Castles of Burgundy – Edição Especial', 'favorite_count': 96, 'popularity_score': 5.146206034871693, 'had_count': 19, 'min_age': 12, 'max_players': 4, 'play_time_minutes': 120, 'played_count': 574, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/36265_t.jpg', 'min_players': 1, 'want_count': 762, 'mysql_id': 34}
