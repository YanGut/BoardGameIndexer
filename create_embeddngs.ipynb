# %%
import os
from tqdm import tqdm # Para barras de progresso

from typing import List, Optional, Union, Dict

from haystack import Document
from haystack import Pipeline

from haystack_integrations.document_stores.chroma import ChromaDocumentStore
from haystack_integrations.components.embedders.ollama import OllamaDocumentEmbedder
from haystack_integrations.components.embedders.ollama import OllamaTextEmbedder
from haystack_integrations.components.retrievers.chroma import ChromaQueryTextRetriever
from haystack_integrations.components.retrievers.chroma import ChromaEmbeddingRetriever

from haystack.components.preprocessors import DocumentCleaner, DocumentSplitter
from haystack.components.converters import PyPDFToDocument
from haystack.components.writers import DocumentWriter
from haystack.document_stores.types import DuplicatePolicy

from mysql.connector import connect
from mysql.connector.connection import MySQLConnection
from mysql.connector.cursor import MySQLCursor
from mysql.connector.cursor import MySQLCursorAbstract
from mysql.connector import Error
from mysql.connector.pooling import MySQLConnectionPool
from mysql.connector.abstracts import MySQLConnectionAbstract

MYSQL_HOST = os.getenv("MYSQL_HOST", "localhost")
MYSQL_PORT = int(os.getenv("MYSQL_PORT", 3306))
MYSQL_USER = os.getenv("MYSQL_USER", "root")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD", "root")
MYSQL_DB = os.getenv("MYSQL_DB", "board_games_db")

# %%
def get_mysql_connection() -> MySQLConnectionPool | MySQLConnectionAbstract:
  print(f"Conectando ao MySQL: host={MYSQL_HOST}, port={MYSQL_PORT}, user={MYSQL_USER}, db={MYSQL_DB}")
  return connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    password=MYSQL_PASSWORD,
    database=MYSQL_DB,
    port=MYSQL_PORT
  )

def fetch_boardgames_from_mysql(conn: MySQLConnectionAbstract) -> list[dict]:
  print("Buscando jogos do MySQL...")
  cursor: MySQLCursorAbstract = conn.cursor(dictionary=True)

  query: str = """
    SELECT 
        jd.id, 
        jd.nm_jogo, 
        jd.idade_minima, 
        jd.qt_favorito, 
        jd.qt_jogadores_max,
        jd.qt_jogadores_min,
        jd.qt_jogou,
        jd.qt_quer,
        jd.qt_tem,
        jd.qt_teve,
        jd.thumb,
        jd.tp_jogo,
        jd.vl_tempo_jogo,
        GROUP_CONCAT(DISTINCT c.nm_categoria SEPARATOR ', ') as categorias,
        GROUP_CONCAT(DISTINCT t.nm_tema SEPARATOR ', ') as temas,
        GROUP_CONCAT(DISTINCT a.nm_profissional SEPARATOR ', ') as artistas,
        GROUP_CONCAT(DISTINCT m.nm_mecanica SEPARATOR ', ') as mecanicas
    FROM jogo_detalhado jd
    LEFT JOIN jogo_categoria jc ON jc.jogo_id = jd.id
    LEFT JOIN categoria c ON c.id = jc.categoria_id
    LEFT JOIN jogo_tema jt ON jt.jogo_id = jd.id
    LEFT JOIN tema t ON jt.tema_id = t.id
    LEFT JOIN jogo_artista ja ON ja.jogo_id = jd.id
    LEFT JOIN artista a ON a.id = ja.artista_id
    LEFT JOIN jogo_mecanica jm ON jm.jogo_id = jd.id
    LEFT JOIN mecanica m ON jm.mecanica_id = m.id
    WHERE jd.id IS NOT NULL AND jd.nm_jogo IS NOT NULL AND jd.nm_jogo != ''
    GROUP BY jd.id, jd.nm_jogo, jd.idade_minima, jd.qt_favorito, jd.qt_jogadores_max,
              jd.qt_jogadores_min, jd.qt_jogou, jd.qt_quer, jd.qt_tem, jd.qt_teve,
              jd.thumb, jd.tp_jogo, jd.vl_tempo_jogo
    LIMIT 1000;
  """
  
  cursor.execute(query)
  results: List[RowType | Dict[str, RowItemType]] = cursor.fetchall()
  cursor.close()
  print(f"Total de {len(results)} jogos buscados do MySQL.")
  return results

mysql_conn: MySQLConnectionAbstract = get_mysql_connection()
boardgames: list[dict] = fetch_boardgames_from_mysql(mysql_conn)
mysql_conn.close()

print(f"Total de jogos encontrados: {len(boardgames)}")
print(f"Exemplo de jogo: {boardgames[0]}")
# Out:
# Conectando ao MySQL: host=localhost, port=3306, user=root, db=board_games_db
# Buscando jogos do MySQL...
# Total de 1000 jogos buscados do MySQL.
# Total de jogos encontrados: 1000
# Exemplo de jogo: {'id': 1, 'nm_jogo': 'Old Dragon 2ª Edição: Livro I - Regras Básicas', 'idade_minima': 12, 'qt_favorito': 69, 'qt_jogadores_max': 10, 'qt_jogadores_min': 1, 'qt_jogou': 74, 'qt_quer': 57, 'qt_tem': 204, 'qt_teve': 1, 'thumb': 'https://storage.googleapis.com/ludopedia-capas/43761_t.jpg', 'tp_jogo': 'b', 'vl_tempo_jogo': 120, 'categorias': None, 'temas': 'Aventura, Fantasia, Literatura, Medieval', 'artistas': None, 'mecanicas': 'Narração de Histórias, Papel e Caneta, Rolagem de Dados, RPG'}

# %%
def prepare_haystack_documents(boardgames_data: list[dict]) -> list[Document]:
    """
    Prepara uma lista de Documentos Haystack a partir dos dados dos jogos de tabuleiro.
    Cada Documento contém informações relevantes sobre o jogo, como nome, tipo, idade mínima,
    número de jogadores, tempo de jogo, categorias, temas, mecânicas e artistas.
    
    Args:
        boardgames_data (list[dict]): Lista de dicionários contendo os dados dos jogos de tabuleiro.
    
    Returns:
        list[Document]: Lista de Documentos Haystack preparados.
    """
    
    print("Preparando Documentos Haystack...")
    haystack_docs: list[Document] = []

    for game in tqdm(boardgames_data, desc="Convertendo dados para Documentos"):
        content_parts: list[str] = [
            f"Nome do jogo: {game.get('nm_jogo', 'N/A')}.",
            f"Tipo: {game.get('tp_jogo', 'N/A')}.",
            f"Adequado para maiores de {game.get('idade_minima', 'N/A')} anos.",
            f"Pode ser jogado por {game.get('qt_jogadores_min', 'N/A')} a {game.get('qt_jogadores_max', 'N/A')} jogadores.",
            f"Tempo médio de jogo: {game.get('vl_tempo_jogo', 'N/A')} minutos.",
            f"Descrição: {game.get('descricao', 'N/A')}." if game.get('descricao') else "Descrição não disponível.",
            f"O jogo se baseia nas seguintes categorias: {game.get('categorias', 'N/A')}." if game.get('categorias') else "Categorias não disponíveis.",
            f"O jogo aborda os seguintes temas: {game.get('temas', 'N/A')}." if game.get('temas') else "Temas não disponíveis.",
            f"O jogo utiliza as seguintes mecânicas: {game.get('mecanicas', 'N/A')}." if game.get('mecanicas') else "Mecânicas não disponíveis.",
        ]
        
        if game.get('categorias'):
            content_parts.append(f"Categorias: {game['categorias']}.")
        if game.get('temas'):
            content_parts.append(f"Temas: {game['temas']}.")
        if game.get('mecanicas'):
            content_parts.append(f"Mecânicas: {game['mecanicas']}.")
        if game.get('artistas'):
            content_parts.append(f"Artistas: {game['artistas']}.")

        content: str = " ".join(content_parts)

        meta: Dict[str, Optional[Union[str, int]]] = {
            "mysql_id": game.get('id'),
            "title": game.get('nm_jogo', 'N/A'), # 'title' é um campo comum para meta
            "min_age": game.get('idade_minima'),
            "max_players": game.get('qt_jogadores_max'),
            "min_players": game.get('qt_jogadores_min'),
            "play_time_minutes": game.get('vl_tempo_jogo'),
            "thumbnail": game.get('thumb'),
            "game_type": game.get('tp_jogo'),
            "categories_list": game.get('categorias', '').split(', ') if game.get('categorias') else [],
            "themes_list": game.get('temas', '').split(', ') if game.get('temas') else [],
            "mechanics_list": game.get('mecanicas', '').split(', ') if game.get('mecanicas') else [],
            "artists_list": game.get('artistas', '').split(', ') if game.get('artistas') else [],
            "favorite_count": game.get('qt_favorito'),
            "played_count": game.get('qt_jogou'),
            "want_count": game.get('qt_quer'),
            "have_count": game.get('qt_tem'),
            "had_count": game.get('qt_teve')
        }
        
        # Remove chaves com valor None dos metadados para evitar problemas com alguns DocumentStores
        meta_cleaned: Dict[str, str | int] = {k: v for k, v in meta.items() if v is not None}

        haystack_docs.append(Document(content=content, meta=meta_cleaned))

    print(f"Total de {len(haystack_docs)} Documentos Haystack preparados.")
    if haystack_docs:
        print("\nAmostra do primeiro Documento Haystack:")
        print(f"Content: {haystack_docs[0].content[:500]}...")
        print(f"Meta: {haystack_docs[0].meta}")
    return haystack_docs

# %%
print("Inicializando o ChromaDocumentStore...")

document_store_for_raw_boardgames: ChromaDocumentStore = ChromaDocumentStore(persist_path="./test_databases/chroma_db_raw_boardgames", collection_name="raw_boardgames")

print(f"ChromaDocumentStore inicializado com persist_path: {document_store_for_raw_boardgames._persist_path} e collection_name: {document_store_for_raw_boardgames._collection_name}")

print(f"ChromaDocumentStore usando path: ./test_databases/chroma_db_raw_boardgames. Documentos existentes: {document_store_for_raw_boardgames.count_documents()}")
# Out:
# Inicializando o ChromaDocumentStore...
# ChromaDocumentStore inicializado com persist_path: ./chroma_db_raw_boardgames e collection_name: raw_boardgames
# ChromaDocumentStore usando path: ./chroma_db_raw_boardgames. Documentos existentes: 1000

# %%
# Embedders
document_embedder: OllamaDocumentEmbedder = OllamaDocumentEmbedder(
  model="nomic-embed-text",
  url="http://localhost:11434",
  # Você pode adicionar outros parâmetros como timeout, etc.
      # generation_kwargs={"num_gpu": 1} # Exemplo se quiser especificar uso de GPU no Ollama
)

text_embedder: OllamaTextEmbedder = OllamaTextEmbedder(
  model="nomic-embed-text",
  url="http://localhost:11434",
  # Você pode adicionar outros parâmetros como timeout, etc.
      # generation_kwargs={"num_gpu": 1} # Exemplo se quiser especificar uso de GPU no Ollama
)

# %%
# Retrievers
query_text_retriever: ChromaQueryTextRetriever = ChromaQueryTextRetriever(
    document_store=document_store_for_raw_boardgames,
)

embedding_retriever: ChromaEmbeddingRetriever = ChromaEmbeddingRetriever(
    document_store=document_store_for_raw_boardgames,
)

# %%
try:
  connection_mysql: MySQLConnectionAbstract = get_mysql_connection()
  raw_boardgames: list[dict] = fetch_boardgames_from_mysql(connection_mysql)
  haystack_docs: list[Document] = prepare_haystack_documents(raw_boardgames)
finally:
  if connection_mysql and connection_mysql.is_connected():
    connection_mysql.close()
    print("Conexão MySQL fechada.")
  
if not haystack_docs:
    print("Nenhum documento Haystack foi preparado. Encerrando o script.")
else:
  print("Inicializando componentes Haystack para indexação...")
  
  print(f"DocumentEmbedder inicializado com modelo: {document_embedder.model} e URL: {document_embedder.url}")
  document_embedder.run(haystack_docs)
  print("Documentos preparados para indexação.")
  
  # Opcional: Limpeza e Divisão de Documentos
  # cleaner = DocumentCleaner() # Remove cabeçalhos/rodapés, linhas em branco etc. (pode não ser necessário)
  # splitter = DocumentSplitter(split_by="word", split_length=200, split_overlap=20) # Divide documentos longos

  writer: DocumentWriter = DocumentWriter(
    document_store=document_store_for_raw_boardgames,
    policy=DuplicatePolicy.OVERWRITE,
  )
  
  # Pipeline de indexação
  indexing_pipeline: Pipeline = Pipeline()
  # Adicione cleaner e splitter se decidir usá-los:
  # indexing_pipeline.add_component("cleaner", cleaner)
  # indexing_pipeline.add_component("splitter", splitter)
  indexing_pipeline.add_component("embedder", document_embedder)
  indexing_pipeline.add_component("writer", writer)
  
  indexing_pipeline.connect("embedder.documents", "writer.documents")
  
  print("Executando pipeline de indexação...")
  
  batch_size: int = 256
  
  print(f"Processando {len(haystack_docs)} documentos em lotes de {batch_size}...")
  for i in tqdm(range(0, len(haystack_docs), batch_size), desc="Indexando documentos"):
    batch_docs: List[Document] = haystack_docs[i:i + batch_size]
    indexing_pipeline.run({
        "embedder": {"documents": batch_docs},
    })
    print(f"Processando lote {i // batch_size + 1} de {len(haystack_docs) // batch_size + 1}...") 
    print(f"Lote {i // batch_size + 1} processado. Total de documentos indexados: {document_store_for_raw_boardgames.count_documents()}")
  print("Pipeline de indexação concluída.")
  print(f"Total de documentos no ChromaDB ({document_store_for_raw_boardgames._collection_name}): {document_store_for_raw_boardgames.count_documents()}")
# Out:
# Inicializando o ChromaDocumentStore...
# ChromaDocumentStore inicializado com persist_path: ./chroma_db_raw_boardgames e collection_name: raw_boardgames
# ChromaDocumentStore usando path: ./chroma_db_jogos. Documentos existentes: 1000
# Conectando ao MySQL: host=localhost, port=3306, user=root, db=board_games_db
# Buscando jogos do MySQL...
# Total de 1000 jogos buscados do MySQL.
# Preparando Documentos Haystack...
# Convertendo dados para Documentos: 100%|██████████| 1000/1000 [00:00<00:00, 51284.51it/s]
# Total de 1000 Documentos Haystack preparados.
#
# Amostra do primeiro Documento Haystack:
# Content: Nome do jogo: Old Dragon 2ª Edição: Livro I - Regras Básicas. Tipo: b. Adequado para maiores de 12 anos. Pode ser jogado por 1 a 10 jogadores. Tempo médio de jogo: 120 minutos. Temas: Aventura, Fantasia, Literatura, Medieval. Mecânicas: Narração de Histórias, Papel e Caneta, Rolagem de Dados, RPG....
# Meta: {'mysql_id': 1, 'title': 'Old Dragon 2ª Edição: Livro I - Regras Básicas', 'min_age': 12, 'max_players': 10, 'min_players': 1, 'play_time_minutes': 120, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/43761_t.jpg', 'game_type': 'b', 'categories_list': [], 'themes_list': ['Aventura', 'Fantasia', 'Literatura', 'Medieval'], 'mechanics_list': ['Narração de Histórias', 'Papel e Caneta', 'Rolagem de Dados', 'RPG'], 'artists_list': [], 'favorite_count': 69, 'played_count': 74, 'want_count': 57, 'have_count': 204, 'had_count': 1}
# Conexão MySQL fechada.
# Inicializando componentes Haystack para indexação...
# DocumentEmbedder inicializado com modelo: nomic-embed-text e URL: http://localhost:11434
# Calculating embeddings: 100%|██████████| 32/32 [07:01<00:00, 13.18s/it]
# Documentos preparados para indexação.
# Executando pipeline de indexação...
# Processando 1000 documentos em lotes de 256...
# Calculating embeddings: 100%|██████████| 8/8 [02:28<00:00, 18.52s/it]
# Document 99f5dc24aa57d37ed564aaa6eebc9ebc07892edd5b6ae46df40308d4b2dc1063 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8dde09176136e5e01b0597b858593ff5572163d3704365757e75021db48cfcbd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9592e0bd5d2a55989e46640d29bf6defdd2af0d4f919dae641113465ea615380 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2187742c1b680e15a3571a47fc363600f3401cbc12bef3355e454761f499c6a2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5fce3e3707107c6c935a0290da092d5b607682f62cb316936d1a0ffdd5690609 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 31456556cec3ce93016d62ae53494d0a32e5f241c5aeb6eb2923739de7594437 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ec11442a77b29fc4c074330fe8ed0a75650ae839428bb7813fb41c807ac091cd contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 348e911bc1c5b660356069af60966501cb604f5d419a145b2604a827ab614fd8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9c318b60d8dae75e54099af565ce7eae0c652766e20a1a85c058238c8a193c5b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8fda782cef0fc56ed7df63f9288408af3bc11ba1cf46b1ce944fb0b420d45913 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3b1ab88c861271d82847cde1d14df0a48ae363f256bca6d5d964facb21e65841 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document dc4040a717da7fdbbf31e79007b7e794b645601cddf4caaeaeb104dc25558763 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 393ada8afacca563fd112e7abba629c208b14c967ae30032a52628bdd6814d7f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 40346fb1818cea64d81414ed9f736d1b86e24c837add5960c5c31e6f6a958027 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0e38dbaeb24f0779692d333d74627b745e106c7d8e40c7f76235146ca22d98af contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 835c66c1ee2386ea874d5226032b1bd03d89208a7c7687313826a940f5e0dce7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document afdb3a1072e3505107fb3131d412618c8ce3a4830e9f9fcbe251795dbaeb36d9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8b57bb267e15f9160f8806082f3cb9a73a461bb70cd3f1843a36278258e1e0c2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document af25c9c835b6924264d15dd381990f2f1276fc60c60136885270b2c496acb46d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 95a0994c7f2781f35e0c5ff51ea56565b0141f14c601a61c1539e758e8404c65 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document eb515d2bdf55554593e6c2df236fcbec414538a7c4eddbe65882805cf9d80898 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2d979255dd9fcf6992da7b6db6f7c57796e51e572f158ee22e7a79936b770999 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 88affd87cd5b9df2b188780dd3c5dc549b89083265fbf9a8b47d4cc8b749d4a8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 471486af86f00e459833af757582f1f1e97802b39506f89df1af6bd9cd53569d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b455b2fda04f5e6da595c578184517a134aa11c831580666df03e3ba0130fdf0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9618d1cea5e15ba06d764c2c70225c1a0376ddd5eeb454917448c5deced26161 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 20704809bed8261304829361093b5b8009639a0a41642d6286cd03c67134df45 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f0cf15388c6bef0b6a262742b1017056804e1a1a451c8a739ac22de941999777 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e47348aac88be52e14b55bb8eb40ae32f7ea9c7788582b38ea08c89570c2e27f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6230ccba3bb3139a1bde16031ca282252272e538a777159bbf8e741c16bf3f7d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f62c5235e2e6fd6cfaf879741415af7c1e33794a71dafefe15e880a3cd2bedd7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7c39c33c391d1537402ac5ab7d799c31fd2199a2c6fc291b9459f69d07c8915e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d2edf0dc65808b38dbad89cb669a5bcb463a9375768e7db7075900537a235d87 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6ac344486383086493bb9d7be688d804a541797f53abc7e7cb68f96789f22b01 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 425f3fe3699ccb265e9c5311eb7c91474f7e9c4724dd41d9e3569fa463317616 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document dcf54b04ef5c3af9a02b7f39d7f6eec63cd88dc3c69d9151234176e1511d0bda contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document be6d03ac6c3089fcde603386b16a799b4613610a7f1503fcc24e82b633d3a0a0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 22c731dc948ad67721a78f586a3c50dbc9b3ed20259d5ddb096262724aa275e2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 722eaebbedbda6ddc23d0ac578082c15f1e7aecf689dc7fe1def101bda0478d3 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f43ef18135316435e2f5b8df3d9a103972d819767087929b8adbad03765713f7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e34a97d3b6ee7f32de226776edfc8195ad0f12821469391c7956821a1828a876 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 73c3ef1698ab8817a93eeab6e9089d8afd2a85f550b650e18876c349a6a1114a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2315c27b271713ec46529cdf9e73bc69c0e4125adc7853021827db15a7ae0f01 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 02174582bc51f3c2171df41292f7affc1cb4c76bb0027385c229f5531e938a8b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9505675cbe65ae83dc00ccb696d230753ec2e94419da8a2560526e94933005e9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 542d85f4550d7613ebf3c2ef6fb11197e4116ece3fd26aba3bd0a08e3dac09db contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bc0f3e01d5af8dd89dd81ad0ee22b959aad32f8d0b3504ac4a0f64cfbf7b0320 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a64761c22823e225ec419aa154ef57c81d0abf2bbe9b8bf28d088bf7bfd28f90 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 60b38bf9ff61076c3b539a371ff4beea1c08a1d7dfd0e42c0bc8c914e5c1ebf9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c1a3de5bd758855aac1e855ff117a55977a56d7d7947970c7613952a3e79bf6b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 351dddc57a1a889bebd9d060957e1eadbd3fedfbd1d881ead397982c660d37c9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 69e8138c1d3aea454bcb186a800347f26bfc27512bece5d95f0242db2ad07f68 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1d8e189f09d621e3f831ee706b279207946ffe97a48f6f721f5167480dafe315 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 39b4bded9097328af64374be86e528ab116fc11feae00f12d23a55bd91400912 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3c697e9eead6b4901bb1649f147a1139fb8ad5fe24701a91d03b33d8a4169e5a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4837d18c2d528695308a6f1a51b9bcce389d0a1f1b2289e22e18b2fc8f635b2d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ff01936275db87428e0ab737ee5dcd7567445793a4be4ebb507bb7262d162b41 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6abd9ee3cb5b40c27ee13cff23fc099e866ec7478f656d724ed8937ef4f870cb contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 152ecf76d236dcabf1ff79166528124f4bfeec98fff5d2c1df538efd1640af2f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 74ac9d746fb2cb300494ba853f2f458166f441350d758f9594f9fcc6aae6d1ec contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document dbac172f46ce8871b613d6082208e135e96ca1bcf407151cd705295403f95231 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 661f0399fe20e8334193ac6c31a846da5d79bb72377b24b50ca3d43dc11ee393 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 83169f211c19e8670bb466f312c5571f88bb5c15c17e7671005e3bbdcefd34d4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f563a50449001ec5e22fa12760026ab7607abce0e1e25293fc064fc5912915a5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d5aa57605ee8bdff995d287f4fd1bb316d653c1de84f9908e91c6b518b48cad1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7860873652c44f24eff7de8fb6aba793672d015e09e8b49c7c5e63137cbf0575 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6e1f3dae1b3ed15335fc431e2d950ce8cf8524002a8b1e91e9a7d1e4ac457655 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1acf261bb891069c8eea7556f9a572ab40ec240fdee37eee0471f15a59454d87 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d00405c70f7f11531d1ef5f4f34208abb17b3c9b4e9004544158ad5b7b761e8d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 409d36d8ab754db530e406015714772ab917b8513c7a93ce52608ae033a775a4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 74b0b4a5049cc875f3e4c0c89de353a03ab369c651a56e64d794c7f42676ccc1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a1902bcd33c33c34c2812d0190a09d814341d5beaec774a80036c1b3678e927f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1e77a4edced419108e70a4f703c3cafd4221d931ef252ed472e4152f51cd2c96 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d1f0296e3ff222bbebfb913bccc334e3422ee9192ed42e066a77c9cb89b46fc8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 29b2e09ea58ffd57f1a5e3a31e960243dba74ad1ad742dfc12a13c357b9e4a50 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1d1d5650ebdc36832cb71d33ecbd9ff2289f0c623b0189d4f72a82dadec6ed75 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 33dcd271bc5526998a17647be59a6e1dda4b4ec7d1e51c59e199bf19a1a7e31a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 493d29a336349096b4f261ff39cc90c45848d68d6519d78eea3628d49954fbd1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 47d87b2fdd5bc1a96b983c24f11407f8f1a303fdb069c6dd83ccce7179a0e1b4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f93c89b1a2817c1dd526f6ee86cdfc8bb5212c624d3de4ad13fbbc3468e2c8f1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 99729adf1c7fd754aee209e77e5b066dc85327e3ea8ada15cfdf7972520a83cc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2204e01a2bb78ff2e0f9c19e1f17cebbe436cbebfb234ade7a2d31b9a761429f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bb46b2699e5dc148e697625772e2dc331828bcc37b8a9391cf4fbd03c493b32b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 327646596a28ad73d2a01e69ce3c4ddbe7f96dcddd4e59d4489b1b84a7cd974c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 74542cb13fa929c89fc4649cd79a48e3dd9c370b7c7a8a9080d9df7ab8e65cea contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 12ca6421c60f50d8240ce3c66f3beb0425029ece9e750e8d990e023748df9746 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a97b2158620205f1a7f58f1046827110588452e87bb6e35f97ab363079c14f8b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b14f3108dcb6c6f5ad45e441bdf327ce181e04a640342709bfd02271d40d0b16 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document baf17487a9c2ce22ffb6cafd78571a22517d59cca232a5841a0e8907cdb93de2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4bbbb189399187b23f7350a819cf3acb4a74d7a959877b6ae4688d5c603e5627 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a66638e9919c6f274c19b7be261bc825129d111f00425b147cdd4fb9f175ae40 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1081eed15d6bcbf9df302078bc6aa4fd749e38c2d934d003892990ef6927a981 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 480083a081caef7c3bc2b2ed0bc5782fe294fcebe4e687927ad40dc7e0b7efb0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 85806a5cf1ce71c9eeb595ff3221142d0eb0ecf53c1661e0bd08597e109e41b4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6dbc55e30e11b1f1b688daa568cb9105482fb3adbc36b8dfc800e0b7b12b241f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c6532c58ee909a612343099f82c65da87522394ae66e5a4cca4f83f7f50a2a48 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a44d7abf2e2dec487dabff80ffc66afdb21a0a21ae489eb7f7683dbd8657d8e8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 34c222ad0fdf49ed037f4dba8d96ab4438091615a0078b76b59defe4b0663b0a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ea16f5945cdc0cac15110be69e9a8f51f8d3e3d9de40876f12032a035c334367 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 892f4a70f7752b70bd80703789a9c1a35342c10c3fb0521b6f5c8e8166ebe60c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 03ce7fcfde7270ff4bb55034d1108827189cd92c05dec8064beccdf8437212d6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 967ee522aafc9304d9a559e1e165de948e1fb9f14b8039b046198d7a145bc640 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ce47ee1c887a693da249b39761b723f502331f631434e4d9dc9169b058316a41 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d4368efde343f1def6b0990d5e34f46ab9e7e367a8129ca923d53f08ac6c2d6e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bafc649d77ad87afcff69a3214a91e968b3b864d8dd3b56d1dd694661c3b5222 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document afe03972ebd4f7ab8ec233a6f7bbfd0173dfb2ec6246b2b40afd58b7903a8447 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8c88cfb403643d37f2c0a4fc04ba0a88470be076225579655cfcf2598c4b3316 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8602ffd1cdb7152a24eb609ec1c2a6311fa670e05781150b43fc38bebe60b995 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ce16e47a3629992e532fe566b25ee1f8259f0c694c14db6107359b08d884b89b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a8d8043492fc5a2310d7ce39b3da21f4cad5f5037ab9c8f1bbce53f9081116a5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 665ebbd16791fb7959702fffb8baa2cf4a657973bde427cde346c7b8b9e718f6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 49ce424ce70563499717065bd57cd8685f2a3b2c676285ba895a00fa2e0d6013 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5d61b591df768f6ad56e31afbc7d21ec83512fb2bc9a99397cffef961b6fee0d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 470a080dbc9a480f2f8fe4cd2f49aec48ffd3131c7cb24a324c447b3fedcd51f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 206ae04793526831a55f0388d3823f9d33e1639c236070ac31cf8ec2c2e25857 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cc784d20b33ece432fb79ad355c920b86a92f5cdfbed8d0023e1b374c8fa0d4b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 59831b54e6ce7307d9a0b907afad62e2fc35b2f9327e0d73ccb696aaa00b27ec contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 70e29798ea6225693d92c0598892a7f8b5139099ac08d3e98e231237a7e39b4b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document aac3406310c653755a6a175d62a7924ec0cac5187e4338b15872c3b0a8f8536f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 31090085c018215c728dc39499cf2d6fabe103b2b34a243d8082e5428a6ca32f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 44c762adb4e354ebf2baec9e2465e0a0b540fe4d09014fcde34f9010de7714a9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1c767d761454168a87d854f5df31d6fdfb5821c7e4bfebe8a29a3d740be6bb05 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document db7d22e37b4c5e866ae6c6622411b0784e40e334bb66cea7b59ce2f576fbe350 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5c3cbe530022f5a9e4de3218445addeb59f12d6a9bbcf05ef2058ea6a6c81ad2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 686879bc8bd53c690d266ec7afd93f1afd2d969cbea25ffa8734b14eb94994f5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 04642f0bf08a19ea492d620baeb2e14e4bdcd44be268f6446287c278e77cce29 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bd6606f078ff84761dc3e5343eb51bd2c3584ab12aa996fe03004d03b5a89f74 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f896e7230842691f9c0d485593c3897378f50f181bbfe225213e8e156fe69883 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4697e4180876b50fcb806c2e80f323d3c85bf357382c0893e7e9c404d9bfed7d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 832232accb387e1f873c8994ed86133ac1df0616dcabf585638cad1a73e284e7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b508efe6335f2a06a9d965dea8c2d388cf435cc9ea3866db2124fb53529d45ac contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 578018b97ce6ebbc8331777cd2c257693f04d40a840935e01580da4fc748ae20 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 73b66a0349fae3cf965bfe2e47d2a7b4341778751ac40d4077b9bde413204d08 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c1f525b53a7043129e48023800d47e035d32cd5a1da8a7a14d194ba3d04d2985 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 544c9574b6b9ee4a24cfaffef087859f93aff7702cd2e94415a6c3b71a7e6c33 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ebd5c4dd1c73f05a72594c8a4c412012cdc59829e36d2bfee4aa7510310aefff contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e28c9ab12ea52f1e73b1e2e85debeb1307c5029f94deee7d07778e209afc7f37 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3bc516719c2f527ec1e29144cc7a2ffa11e5b916aaad832d33c08333b610c837 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 73e736b517b03485b5eb7d006a64eb53264bf78320fe77090e95d22ba46567dc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c8f7fc9d3b2c3836295d1677113f29da6224e885d21817eab2843f42011bc89b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document be2eb6778704d09a372b2ed47b0a49a7f3eb5321b6345633bb98fa9bb8a6e304 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a7c333a016b79a21415740fdfb6f1835c17e1374e4bb4e647e9e79e56a4fe665 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2a5ed631c2875ad995672aab6788ea7ee0fe539175547c0acb189f9ab699e2db contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 03a993e198b712c992613a9bfc5de352d8581dd5243323bf6ded0fe49e9aee46 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document fede07b0e945e48b69f2097e0f30f272990d88d8ba0942e004afacf9db116f07 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document df4022e556db2f865e2824525695daf67a6322fea94b54b34d25a6a03d142788 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document daca7f9e7b9a50135c2d4260a2381e04421cb74976d67a7cc10d2b9b165add77 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 60bfcbeb79bc0863a1e23d8c204442427e07564367ec45e5c70ecaa3615e0114 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1d45cfd1ae1ce373dfccb4bb7c6ddb03db24eed1a9546d6486bdf775beb26def contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5a32650b6870f599b4ab49631874e6618bf61bf659837f771a5256228d44798a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 538e1b2508b82909e8cb6b6aca7b8683355e7eba4f80a0de96e44edcff5d8f7f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ac261d2ea209d165978e37931cdc3ee8ede2899050b38fbf20fefe661d52a04e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f4722eb25f419e8eba11f9c6180920e4fff7ada79a39e418f61ea421427147f5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c0f8ad52eab3971905e6f590b319a21630e8b6a96bcf86fecb68d2b7badaf41f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ff2339748bfc0a301af42c83b4093491984f8e90d46a8a48845cc385b0a332c0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document fcd27019d8a1cbaa77a359bfc1bff5ae5b3cd192ac33b4102b508f85d31eb236 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8940609d24314a8f12a18d191d587e4caef2c2861e5eddba877a30cdce2fe897 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3e0fe79a02f3df2b4260461dd784c2e8de0714120b634475ee7c622500baa430 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d25fd8f0d0233d724d00c12bcf6f7a581c519c6a36beb29f622b0ea4e205139b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5d051e8857b1526f3c5e211c075948a12fdc8dad1523a7c7c606360a8413680d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ecf5d490f21c3ab52ea5f83609e9dfbea486052c6d23e97205283e7e082b5b9c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 452e5d4c65103af4e69cadf3800e8093b5293ccc9261cc904157694ffce63699 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 197bac2fc804a07e26ac4b649159923bfb2746b3f9b9a03c39e87ccb03a47be0 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3d0a89001382d10d751322725a556d712ba0831e05b34c469e14f61342857ee4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5bc982ee852d6954df89079b48670ed0a6ef0acadbead86e98478a65cddd833e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 12be4abdb2730a853764dae214dc54ae0ed44ab878d0bb296215c19b2d61bf6a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0e7457767adf9d972855722fdfd7e25b9511f651205921869475cc1075756d45 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 747574ae7a6ce15a5c8939f4bb85eccecd1b6fd02c3ad20da1533fac0c4247ff contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 68ebfdc7dd9849634f172d39a4ee9a1ce6e5345574ea2b7681c33bd498d50734 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 43a59e48da476bfa06f27b9e864a96e839cc86a7f548540cbe4fe7864abf2297 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 1a183b67702531e32a1982136611fc4667156131363d1b4f63b22f2b64beae84 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8c76cc012d316b13004f896e686f913484351bdae6b30f6653974c9d4d6a9c52 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# ...
# Document 138171e3fb40bfaf1a3e21a2bd88468333020c1bed4a2908c0f7b0278830b720 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7dff9482877537117fa629b7568e63ab53965e6e504bf08b0c8a2293d8376ec6 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5bb037bb430a706a5733f13cd02fc41118d70258d788a8abe0b8cd9090a786ef contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c100656d92b89b88f63d2f6d6060758b7f890d42ad070eda78044bbe0b50df5d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9737103d20ba753b67211e9af2a5e5028eaf6afd45cf9cadad9f9afab0c92b2c contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 625d9762cac33b0d8a44185ba24a3ea32dcc3779deb9cb80ac6a924df0cffd3f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2a6db2a3ec8b8aaa13f7455564f3db12160d888ee8566e7233534fda8362653a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 008f005048dc8db1fd993f05070e6a5b7d381297a919412a04d8c7f5a02da79e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 34d64aa96a4cc57d8bc1801d29be1e373de06b12a29591c4232478ebb5f99fdc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document dfc0a1bbc0ddc54f2ee07f26343ca04650c43523a4d0545549bf893bab3ecc9e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 878c45fb68d20aab030d2ce734f2ab7c9faeabacbc30f188667ba969b896951a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 784d2ba8c778e018d4f2448ff053a6d31933fbae84cb9961a2f027540f4d8152 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d7304a1092b3ee5609888945247f2e1a83d47013ad5fed6e2c27cb8238689955 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e5208227d2ff25a833a5318f5972b17b709bbe8b6f1e444e3dd4066fdc70eec7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document cfe824c0bebdeefce270b9fb86e84b3b43f14f2251f3215d4fe713af704ee799 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9727adff388720fd473b0de7449acfee313e455d670519f53e772e30b46e7180 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2a9e872a4981aab95e009d01f423ce1ef54c29511a415f5717f94d879d8561f9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f5fb60e569f0f76cb066c2951a35fb1f2cc76582e2ab7ec0a4ef7d300d3f4915 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a637b7e8d3791ef9172414ac68eab14529fa0b97d0bf22f6c848a66fae3b979f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9611f7aa59de51b635711d1514a5bd4095ed0909bcea59c5b64202bb46dec8df contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 077cf03fa293b4b2e423723f7fa1aa4aef0512f5a2805867ff089ba2fc3a5c35 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 622b8cc328c3f2de22ed8672a6cbae583c235bafe2c60850374d7098c05a0977 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document f46e85409eddfb3455f9083b40393f4ac14ce2b09e179a857377635c5fa55625 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9b53adb427c47dedff012c21fa42cad9419d2f7734c23b6b0907ff95eb12a52e contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 715be00cfa60709d442fcb88ee73f761fae55f886b74aed22276f4af1759e58f contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8d2731b3087d77215387a8d15f9868b19f31333af29c82366b2a3e81b10436c7 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bd7bac110689448446b73981c96db30464053656b8b656b9a71b77a5a09424af contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5af5fa1f46cfb34f747bb1e40a70d0f42c00d2f7f3773a7d1d3f0f2fe915c27d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 79186ca125a1f9939ab6ca7ae02737610498a8108ede7f3bde22d268a65396b8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2615216b204ea56bfcbbce3f51484b5ee46b0ea25e7f121b8055dd3538698638 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0d4b66342eaf48bc8a31ab1df2db3e9b15201f11c41a640b404d41dbb37f672b contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e5d4dfbb3836bb8fd4fe05fbdcd39319bb9a029ae7a98b269b4907dd0d0d5187 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document bf9fcf23bc55dee7022bfc2d738af4f85f87832232342197a1fc51232819b6c5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 3f41c30efc20683f9e828668c9e0fc213b13730f65deab95d94e657c1acaade2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8bd6354db8ae69f2f636cc7e1676b5b84401320dbcabde8462830374b701c8a5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 91a1c8af83bec7e551aed8f39e367234ecae2d900dfab5e4b3c744453d45d56d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4dad1b57dd9b2293a78559eea4cd21078ac40ee5670c3aead2f6a7f3cfafa094 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 7f6f12ead28a0fbf1f42e751b2f49edef8159719b9e1141c9cf958d3197b6f69 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 358af2f0016be7774596d50acf3ff36b78b98142cb547290aadb724dac6ac353 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document ef91459c993caa9b3671f2294002423c1daabfa539d05e8f1d88178895f27a5a contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 50ebd9bdf23a9a35776cbd2eb0edd56ade0c5fb7840cf8552e6180a0addf8c11 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 40f1d9988e68789175c3f494c0a6c8fb863dc63bbf8b42c2dcb7776eede8c2b8 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2d0d98e84d65a6518e0197bbdbffe7338862d03008462eed821a73be2be64d63 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4fdc410c47ea754a53921bcc6bedde02c44f694a38caa630e85c665532fb4ad5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b2822bb570d41a837de9fce7ef605eee465cc393cfb5a7476093293193b1bfd2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0993da74dab22ca4d51dbb3e2fc4bcaa64889dd1b0531b83021c81625ab2f2d1 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document e12040e1ea3f7d1262df2b4bbd848bfa4faee7ca276e07a060afa985e3be27f5 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document c2a5be3132ca9852eef6e00e69dacf5ef20b7dd9187db98863afbb69feca89eb contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document d2ecc28649b1f0c24ef46639b552b33034bbc61189de3b2d807f550d754617a2 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 9ce98dc0ab9e69ce26bd309675ebac6ae3c1f6bf60883077976bd57a98b77d06 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 77b10a1c30819136e1e34acf298df6cbe3a74f2d228993119cb7d5221af5b0dc contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 6b10dd5d60cfd1347443068798442d6a7e0682fa6863e5d5db8da4d8d25be2c4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document a8cfc990198d19eca65c314e03e4d5aef7b51463a05c743136fdf81a7fead7d9 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2a8fcbe24b3ca8e5978c35da695902c6966fc3f14378ff3c050e73f531ae2548 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 431f53babdd3116dff31b4fcddc7a09b29c16c912b626eec4d144b253b676a13 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5cc1d04b71adfa7e1991169c407643b79ceb4a7790fa0d10ff93851f9dd153f4 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document abdd3a53eaed7958750a547b982b7224abe08b2b753302419f54842f4f44f425 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document 416879fe0245ab081898ed3ab13289a116f419c9b001db3f8e4988cdf509bc20 contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Document b999ce4f7f77442337381262b171aeba8ae2f71600d0117bb8f96082403cf88d contains `meta` values of unsupported types for the keys: categories_list, themes_list, mechanics_list, artists_list. These items will be discarded. Supported types are: str, int, float, bool.
# Indexando documentos: 100%|██████████| 4/4 [08:54<00:00, 133.67s/it]
# Processando lote 4 de 4...
# Lote 4 processado. Total de documentos indexados: 1000
# Pipeline de indexação concluída.
# Total de documentos no ChromaDB (raw_boardgames): 1000

# %%
print(f"ChromaDocumentStore para teste de query inicializado com persist_path: {document_store_for_raw_boardgames._persist_path} e collection_name: {document_store_for_raw_boardgames._collection_name}")

query_text_retriever: ChromaQueryTextRetriever = ChromaQueryTextRetriever(
    document_store=document_store_for_raw_boardgames,
)

print("\nTestando Opção 2: OllamaTextEmbedder + ChromaEmbeddingRetriever")
text_embedder = OllamaTextEmbedder(
    model="nomic-embed-text", 
    url="http://localhost:11434"
)

embedding_retriever = ChromaEmbeddingRetriever(document_store=document_store_for_raw_boardgames)

querying_pipeline_option2: Pipeline = Pipeline()
querying_pipeline_option2.add_component("text_embedder", text_embedder)
querying_pipeline_option2.add_component("embedding_retriever", embedding_retriever)
querying_pipeline_option2.connect("text_embedder.embedding", "embedding_retriever.query_embedding")

results_option2 = querying_pipeline_option2.run({
    "text_embedder": {"text": "jogo de estratégia para dois jogadores com tema medieval"},
    "embedding_retriever": {"top_k": 3}
})

if results_option2["embedding_retriever"]["documents"]:
    print("Resultados da Opção 2:")
    for doc in results_option2["embedding_retriever"]["documents"]:
        print(f"  Title: {doc.meta.get('title', 'N/A')}, Score: {doc.score:.4f}")
        print(f"  Content snippet: {doc.content[:200]}...")
        print(f"  Meta: {doc.meta}")
        print("\n")
else:
    print("Nenhum resultado encontrado pela Opção 2.")
# Out:
# ChromaDocumentStore para teste de query inicializado com persist_path: ./chroma_db_raw_boardgames e collection_name: raw_boardgames
#
# Testando Opção 2: OllamaTextEmbedder + ChromaEmbeddingRetriever
# Resultados da Opção 2:
#   Title: Torres, Score: 399.5052
#   Content snippet: Nome do jogo: Torres. Tipo: b. Adequado para maiores de 12 anos. Pode ser jogado por 2 a 4 jogadores. Tempo médio de jogo: 60 minutos. Categorias: Estratégia Abstrata. Temas: Medieval. Mecânicas: Cerc...
#   Meta: {'max_players': 4, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/939_t.jpg', 'title': 'Torres', 'favorite_count': 24, 'min_age': 12, 'have_count': 329, 'had_count': 121, 'mysql_id': 854, 'want_count': 331, 'game_type': 'b', 'min_players': 2, 'played_count': 514, 'play_time_minutes': 60}
#
#
#   Title: The Castles of Burgundy – Edição Especial, Score: 399.5975
#   Content snippet: Nome do jogo: The Castles of Burgundy – Edição Especial. Tipo: b. Adequado para maiores de 12 anos. Pode ser jogado por 1 a 4 jogadores. Tempo médio de jogo: 120 minutos. Categorias: Estratégia Abstra...
#   Meta: {'played_count': 574, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/36265_t.jpg', 'had_count': 19, 'want_count': 762, 'title': 'The Castles of Burgundy – Edição Especial', 'min_players': 1, 'min_age': 12, 'max_players': 4, 'mysql_id': 34, 'have_count': 392, 'favorite_count': 96, 'play_time_minutes': 120, 'game_type': 'b'}
#
#
#   Title: Era: Idade Medieval, Score: 399.6102
#   Content snippet: Nome do jogo: Era: Idade Medieval. Tipo: b. Adequado para maiores de 8 anos. Pode ser jogado por 1 a 4 jogadores. Tempo médio de jogo: 45 minutos. Categorias: Jogo de Dados, Miniaturas. Temas: Civiliz...
#   Meta: {'max_players': 4, 'min_players': 1, 'mysql_id': 649, 'min_age': 8, 'favorite_count': 43, 'had_count': 106, 'title': 'Era: Idade Medieval', 'game_type': 'b', 'played_count': 801, 'thumbnail': 'https://storage.googleapis.com/ludopedia-capas/21031_t.jpg', 'have_count': 770, 'want_count': 450, 'play_time_minutes': 45}
